# %%
import sys
sys.path.append("..")

from bank.Absorption.packed_absorption_general_transfer_units_base import (
    PackedAbsorptionGeneralSpec,
    solve_packed_absorption_general,
)

# Problem data
spec = PackedAbsorptionGeneralSpec(
    V_total=100.0,        # kmol/h
    L_total=90.0,         # kmol/h
    y1=0.020,
    y2=0.0020,
    x2=0.0,
    m=0.68,
    z=4.0,                # m
    S=1.0,                # m^2 (set as needed)
    k_ya=50.0,            # example values
    k_xa=80.0,
)

res = solve_packed_absorption_general(spec)

for k, v in res.items():
    print("\n", k)
    print(v)
# Out:
#  inputs
# {'V_total': 100.0, 'L_total': 90.0, 'y1': 0.02, 'y2': 0.002, 'x2': 0.0, 'm': 0.68, 'x1_given': None, 'z_given': 4.0, 'S_given': 1.0, 'A_override': None, 'use_solute_free_for_A': True}
#
#  flows
# {'V_prime': 98.0, 'L_prime': 90.0, 'V_used_for_A': 98.0, 'L_used_for_A': 90.0, 'A_basis': 'solute_free'}
#
#  compositions
# {'x1': 0.01964636542239686, 'x2': 0.0, 'y1': 0.02, 'y2': 0.002, 'y1_over_m': 0.029411764705882353}
#
#  equilibrium
# {'m': 0.68, 'y_star1': 0.013359528487229865, 'y_star2': 0.0, 'x_star1': 0.029411764705882353, 'x_star2': 0.0029411764705882353}
#
#  absorption_factor
# {'A': 1.3505402160864346}
#
#  analytical
# {'N_theoretical': 4.009163899473305, 'NOG_overall_closed_form': 4.641674811844394, 'NOL_overall_closed_form': 3.484781165136086}
#
#  heights_from_z
# {'HETP': 0.9977142617006731, 'HOG_from_z_over_NOG': 0.8617579132844464, 'HOL_from_z_over_NOL': 1.147848260894682}
#
#  coefficient_based
# ...
